# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Rike\\Downloads\\ALL_LATEST_Sui_deaths.csv')
df.head(50)
# Out:
#                IND_ID    IND_CODE IND_UUID IND_PER_CODE  DIM_TIME  \
# 0   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2013
# 1   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2005
# 2   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2015
# 3   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2003
# 4   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2003
# 5   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2018
# 6   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2016
# 7   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2008
# 8   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2007
# 9   16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2013
# 10  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2006
# 11  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2019
# 12  16BBF41SDGSUICIDE  SDGSUICIDE  16BBF41   SDGSUICIDE      2004
# ...

# %%
df['DIM_AGE'].unique()
# Out:
# array(['TOTAL', 'Y_GE85', 'Y15T19', 'Y15T24', 'Y15T29', 'Y25T34',
#        'Y30T49', 'Y35T44', 'Y45T54', 'Y55T64', 'Y65T74', 'Y75T84'],
#       dtype=object)

# %%
# get rid of rows with odd age_groups
df = df[~df['DIM_AGE'].isin(['Y15T19', 'Y15T29', 'Y30T49'])]

# %%
df.nunique()
# Out:
# year                 20
# country             194
# DIM_SEX               3
# DIM_AGE               9
# rate_per_100000    7116
# dtype: int64

# %%
df.drop(columns = ['IND_ID', 'IND_CODE','IND_UUID', 'IND_PER_CODE', 'DIM_TIME_TYPE', 'DIM_PUBLISH_STATE_CODE', 'IND_NAME' ], inplace=ce = True)

# %%
df.drop(columns = ['DIM_GEO_CODE_M49', 'DIM_GEO_CODE_TYPE', 'RATE_PER_100000_NL', 'RATE_PER_100000_NU'], inplace = True)

# %%
df.rename(columns = {'GEO_NAME_SHORT' : 'country', 'RATE_PER_100000_N' : 'rate_per_100000', 'DIM_TIME' : 'year'}, inplace= True)

# %%
df
# df.shape
# Out:
#        year        country DIM_SEX DIM_AGE  rate_per_100000
# 0      2013         Uganda  FEMALE   TOTAL           1.7100
# 1      2005          Egypt  FEMALE   TOTAL           2.3000
# 2      2015          Egypt   TOTAL   TOTAL           3.2800
# 3      2003        Uruguay    MALE   TOTAL          24.7415
# 4      2003     Uzbekistan   TOTAL   TOTAL           9.0200
# ...     ...            ...     ...     ...              ...
# 17513  2019           Oman    MALE  Y75T84          15.9600
# 17514  2019        Algeria    MALE  Y75T84           5.8900
# 17515  2019        Lesotho    MALE  Y75T84         228.6600
# 17516  2019    El Salvador   TOTAL  Y75T84           7.6000
# 17517  2019  Guinea-Bissau  FEMALE  Y75T84          34.7500
#
# [15912 rows x 5 columns]

# %%
df_ue85 = df[df['DIM_AGE'] == 'Y_GE85']
df_ue85.tail(50)
# Out:
#        year                                country DIM_SEX DIM_AGE  \
# 12119  2019                                 Uganda  FEMALE  Y_GE85
# 12120  2019                               Thailand    MALE  Y_GE85
# 12121  2019                                  Congo    MALE  Y_GE85
# 12122  2019                 Bosnia and Herzegovina    MALE  Y_GE85
# 12123  2019                                Belarus  FEMALE  Y_GE85
# 12124  2019                                Albania   TOTAL  Y_GE85
# 12125  2019                                  Italy   TOTAL  Y_GE85
# 12126  2019                                Finland    MALE  Y_GE85
# 12127  2019                                Georgia   TOTAL  Y_GE85
# 12128  2019                                  China    MALE  Y_GE85
# 12129  2019                                  Congo  FEMALE  Y_GE85
# 12130  2019                 Bosnia and Herzegovina  FEMALE  Y_GE85
# 12131  2019                               Malaysia  FEMALE  Y_GE85
# ...
